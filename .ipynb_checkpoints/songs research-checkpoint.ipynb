# %%
import requests
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
jan = pd.read_csv('data/January17.csv', encoding='UTF-8')
feb = pd.read_csv('data/February17.csv', encoding='UTF-8')
march = pd.read_csv('data/March17.csv', encoding='UTF-8')
april = pd.read_csv('data/April17.csv', encoding='UTF-8')
may = pd.read_csv('data/May17.csv', encoding='UTF-8')
june = pd.read_csv('data/June17.csv', encoding='UTF-8')
july = pd.read_csv('data/July17.csv', encoding='UTF-8')
august = pd.read_csv('data/August17.csv', encoding='UTF-8')
september = pd.read_csv('data/September17.csv', encoding='UTF-8')
october = pd.read_csv('data/October17.csv', encoding='UTF-8')

# %%
jan = jan[['Date', 'Who', 'What', 'Link', 'Best', 'Worst', 'Score (1-10)', 'Year']]
feb = feb[['Date', 'Who', 'What', 'Link', 'Best', 'Score (1-10)','Year']]
march = march[['Date', 'Who', 'What', 'Link', 'Best', 'Score (1-10)', 'Year']]
april = april[['Date', 'Who', 'What', 'Link', 'Best', 'Score (1-10)', 'Year']]
may = may[['Date', 'Who', 'What', 'Link', 'Best', 'Score (1-10)', 'Year']]
june = june[['Date', 'Who', 'What', 'Link', 'Best', 'Score (1-10)', 'Unnamed: 7', 'Year']]
july = july[['Date', 'Who', 'What', 'Link', 'Best', 'Score (1-10)', 'Unnamed: 7', 'Year']]

# %%
jan['month'] = 'january'
feb['month'] = 'february'
march['month'] = 'march'
april['month'] = 'april'
may['month'] = 'may'
june['month'] = 'june'
july['month'] = 'july'
august['month'] = 'august'
september['month'] ='september'
october['month'] ='october'

# %%
feb = feb.drop(0)
march = march.drop([0, 32, 33, 34, 35, 36, 37, 38])
april = april.drop(0)
may = may.drop(0)
june = june.drop(0)
july = july.drop(0)
august = august.drop(0)
september  = september.drop([0,30])

# %%
allpd = pd.concat([jan, feb, march, april, may, june, july, august, september, october])
allpd.rename(columns={'Score (1-10)': 'Score'}, inplace=True)

# %%
allpd['Date'] = pd.to_datetime(allpd['Date'], format='dd/mm/yyyy', infer_datetime_format=True)

# %%
allpd['Score'] = allpd['Score'].map(lambda x: str(x).replace(',', '.'))
allpd['Score'] = allpd['Score'].astype(float)
scores = allpd['Score'].tolist()

# %%
scores_series = allpd.set_index('Date')['Score']

# %%
scores_series.describe()
# Out:
# count    285.000000
# mean       8.156842
# std        1.325560
# min        0.000000
# 25%        7.600000
# 50%        8.000000
# 75%        9.000000
# max       11.000000
# Name: Score, dtype: float64

# %%
scores_series.plot()

# %%
months_dates = {'jan': ['2017-01-01', '2017-01-31'], 
                'feb': ['2017-02-01', '2017-02-28'], 
                'march': ['2017-03-01', '2017-03-31'],
               'april': ['2017-04-01', '2017-04-30'], 
               'may': ['2017-05-01', '2017-05-31'],
               'june': ['2017-06-01', '2017-06-30'],
               'july': ['2017-07-01', '2017-07-31'],
               'aug': ['2017-08-01', '2017-08-31'],
               'sept': ['2017-09-01', '2017-09-30'],
               'oct': ['2017-10-01', '2017-10-13']}
for index in months_dates:
    plt.figure()
    plt.title(index)
    month = scores_series[months_dates[index][0]: months_dates[index][1]]
    month.plot()
    print(index)
    print(month.describe())
    print()
# Out:
# july
# count    29.000000
# mean      8.127586
# std       1.152914
# min       5.000000
# 25%       7.500000
# 50%       8.000000
# 75%       9.000000
# max      10.000000
# Name: Score, dtype: float64
#
# feb
# count    26.000000
# mean      8.492308
# std       1.873803
# min       0.000000
# 25%       8.500000
# 50%       8.550000
# 75%       9.500000
# max      10.000000
# Name: Score, dtype: float64
#
# oct
# count    11.000000
# mean      8.345455
# std       0.994348
# min       6.500000
# 25%       8.000000
# 50%       8.500000
# 75%       9.000000
# max      10.000000
# Name: Score, dtype: float64
#
# sept
# count    27.000000
# mean      7.818519
# std       1.767013
# min       0.000000
# 25%       7.650000
# 50%       8.000000
# 75%       8.400000
# max      10.000000
# Name: Score, dtype: float64
#
# june
# count    28.000000
# mean      8.235714
# std       0.738975
# min       7.000000
# 25%       7.950000
# 50%       8.000000
# 75%       8.500000
# max      10.000000
# Name: Score, dtype: float64
#
# may
# count    29.000000
# mean      7.965517
# std       1.811723
# min       0.000000
# 25%       8.000000
# 50%       8.300000
# 75%       8.900000
# max      10.000000
# Name: Score, dtype: float64
#
# march
# count    29.000000
# mean      8.182759
# std       1.076392
# min       6.000000
# 25%       8.000000
# 50%       8.000000
# 75%       8.700000
# max      10.000000
# Name: Score, dtype: float64
#
# jan
# count    29.000000
# mean      8.362069
# std       1.143745
# min       5.300000
# 25%       7.800000
# 50%       8.500000
# 75%       9.000000
# max      10.000000
# Name: Score, dtype: float64
#
# aug
# count    29.000000
# mean      8.131034
# std       1.175373
# min       5.900000
# 25%       7.500000
# 50%       8.000000
# 75%       8.600000
# max      11.000000
# Name: Score, dtype: float64
#
# april
# count    28.000000
# mean      8.110714
# std       1.247617
# min       4.000000
# 25%       7.500000
# 50%       8.000000
# 75%       9.000000
# max      10.000000
# Name: Score, dtype: float64

# %%
allpd['Year'].hist()

# %%
normcolumns = ['Date', 'Who', 'What', 'Link', 'Best', 'Worst', 'Score', 'Year', 'month']
unnamded_columns = [x for x in allpd.columns if x not in normcolumns]
#unnamded_columns.append('Date')

# %%
alldata = allpd.reset_index()

# %%
#emotions_raw = list(set(np.concatenate(allpd[unnamded_columns].values)))

# %%
emots = []
for c in unnamded_columns:
    emots.extend(alldata[c].dropna().index)

# %%
def nice_emotion_writer(index):
    piece = alldata.iloc[index]
    piece = piece.fillna('-')
    s = '{0} - {1}, {2}, score: {3}\n'.format(piece['Who'], piece['What'], piece['month'], piece['Score'])
    for c in unnamded_columns:
            if piece[c] != '-':
                s += "{0}\n".format(piece[c])
    return s

# %%
with open('albums_rare_expressions.txt', 'w', encoding='utf-8') as wf:
    for i in emotion_indexes:
        wf.write(nice_emotion_writer(i) + "\n\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-00ecb599f7d9> in <module>()
#       1 with open('albums_rare_expressions.txt', 'w', encoding='utf-8') as wf:
# ----> 2     for i in emotion_indexes:
#       3         wf.write(nice_emotion_writer(i) + "\n\n")
#
# NameError: name 'emotion_indexes' is not defined

# %%
excellent_albums = alldata[alldata['Score'] > 9.4][['Who', 'What', 'Score']]
excellent_albums.sort_values(by='Score', ascending=False)
# Out:
#                                                  Who  \
# 66                                    Arctic Monkeys
# 7                                          Daft Punk
# 64                                         Иван Дорн
# 216                              Nothing But Thieves
# 213                                            alt-J
# 212                                            alt-J
# 202                                  Mayer Hawthorne
# 188                                      The Beatles
# 177  Pink Floyd - Dark Side Of The Moon (Full Album)
# 153                                     Dan Auerbach
# 140                                         Blossoms
# 128                                  Aretha Franklin
# 102                                Justin Timberlake
# 68                                          Bastille
# 233                           Tricky                              Ununiform
# 251                      Miley Cyrus                            Younger Now
# 130                    Stevie Wonder                           Talking Book
# 269                         dePresno           The Last of the Romantics EP
# 108                     Zara Larsson                                So Good
# 85                      Daniel Shake                           Loosen Me Up
# 15                         Lady Gaga                                 Joanne
# 101                 The War On Drugs                      Lost In The Dream
# 39                      Depeche Mode                        Speak And Spell
# 62                            Stella                          Works for You
# 98                  The War On Drugs                          Slave Ambient
# 90               Bombay Bicycle Club              So Long, See You Tomorrow
# 104                            Kelis                                  Tasty
# 86                         Lady Gaga                      The Fame Monster
# 198                      Tom Grennan       Found What I've Been Looking For
# 38                            Police                          Synchronicity
# 155                      Fleet Foxes                               Crack-Up
# 190                 Michael McDonald                              Wide Open
# 11                       Say Lou Lou                        Lucid Dreaming
# 88                    Ellie Goulding                                 Lights
# 218         Unknown Mortal Orchestra               Unknown Mortal Orchestra
# 232                           Fergie                        Double Dutchess
# 245                     Leon Russell                     On a Distant Shore
# 12                       Tame Impala                               Lonerism
# 72                        White Lies                                Friends
# 238                        Tim Barry                             High on 95
# 142                      Lostboycrow             Traveler: The First Legend
# 243                   Princess Nokia                            1992 Deluxe
# 157                      Jack & Jack                                   GONE
# 184                   Blood Cultures                         Happy Birthday
# 45                    Gregory Porter                   Take Me To The Alley
# 148  The Miseducation of Lauryn Hill                            Lauryn Hill
# 267                       Tony Allen                             The Source
#
#      Score
# 10     7.0
# 192    7.0
# 139    7.0
# 147    7.0
# 158    7.0
# 163    7.0
# 164    7.0
# 187    7.0
# 194    7.0
# 117    7.0
# 199    7.0
# 201    7.0
# 221    7.0
# 228    7.0
# 233    7.0
# 251    7.0
# 130    7.0
# 269    7.0
# 108    7.0
# 85     7.0
# 15     7.0
# 101    7.0
# 39     7.0
# 62     7.0
# 98     7.0
# 90     7.0
# 104    7.0
# 86     7.0
# 198    6.9
# 38     6.5
# 155    6.5
# 190    6.5
# 11     6.5
# 88     6.0
# 218    6.0
# 232    6.0
# 245    6.0
# 12     6.0
# 72     6.0
# 238    5.9
# 142    5.5
# 243    5.3
# 157    5.0
# 184    4.0
# 45     0.0
# 148    0.0
# 267    0.0

# %%
#excellent_albums.to_csv('albums_with_rate_more_than_9-4.csv')
#bad_albums.to_csv('albums_with_rate_less_than_7-1.csv')
#norm_albums.to_csv('albums_with_rate_less_than_9-4_but_more_than_7-0.csv')

# %%
norm_albums = alldata[(alldata['Score'] > 7.0) & (alldata['Score'] <= 9.4)][['Who', 'What', 'Score']]
norm_albums.sort_values(by='Score', ascending=False)
# Out:
#                              Who  \
# 211                        Alt-J
# 284                Róisín Murphy
# 29           Panic! At The Disco
# 1                         Rhodes
# 106                    James Bay
# 81                    Matt Corby
# 222                          Rex
# 136                  Frank Ocean
# 40                  Depeche Mode
# 41                   Dean Martin
# 48                          Muse
# 131                Elvis Presley
# 53                          Muse
# 54                          Muse
# 126                           LP
# 144                        alt-J
# 196          Death Cab for Cutie
# 71                    Matt Wills
# 116                  Alicia Keys
# 114                   Alex Clare
# 78                        Rhodes
# 125                 Thomas Azier
# 224                        Kaleo
# 283                      Alvvays
# %%
bestalbums2017 = albums2017[albums2017['Score'] > 8.9]
bestalbums2017 = bestalbums2017.sort_values(by='Score', ascending=False)
bestalbums2017[['Who', 'What', 'Score']]
# Out:
#                      Who                        What  Score
# 153         Dan Auerbach           Waiting on a Song   10.0
# 64             Иван Дорн            Jazzy Funky Dorn   10.0
# 113         Parov Stelar          The Burning Spider   10.0
# 216  Nothing But Thieves              Broken Machine   10.0
# 213                alt-J                     RELAXER   10.0
# 61            Ed Sheeran                      Divide   10.0
# 249    Kamasi Washingtom    Harmony of Defference EP    9.9
# 274          St. Vincent                MASSEDUCTION    9.8
# 264            Rationale                   Rationale    9.8
# 223    Rex Orange County            Apricot Princess    9.8
# 161          Royal Blood     How Did We Get So Dark?    9.8
# 208     Albin Lee Meldau                   Bloodshot    9.5
# 235                 Niia                           I    9.5
# 60        Rag'n'Bone Man                       Human    9.5
# 151                Lorde                   Melodrama    9.5
# 150       London Grammar  Truth Is a Beautiful Thing    9.5
# 109            Ivan Dorn                         OTD    9.5
# 180         Lana Del Rey               Lust For Life    9.0
# 144                alt-J                     RELAXER    9.0
# 126                   LP                 Lost on You    9.0
# 125         Thomas Azier                       Rouge    9.0
# 71            Matt Wills           Set You Free - EP    9.0
# 281            Sam Smith        The Thrill Of It All    9.0

# %%
worstalbums2017 = albums2017[albums2017['Score'] < 7.5]
worstalbums2017 = worstalbums2017.sort_values(by='Score', ascending=False)
worstalbums2017[['Who', 'What', 'Score']]
# Out:
#                   Who                              What  Score
# 260        TOKiMONSTA                        Lune Rouge    7.3
# 62             Stella                     Works for You    7.0
# 164   Imagine Dragons                            Evolve    7.0
# 251       Miley Cyrus                       Younger Now    7.0
# 233            Tricky                         Ununiform    7.0
# 108      Zara Larsson                           So Good    7.0
# 192      Brockhampton                     SATURATION II    7.0
# 194   Alexander Biggs      Still You Sharpen Your Teeth    7.0
# 147         Bleachers                          Gone Now    7.0
# 139       Julie Byrne                Not Even Happiness    7.0
# 269          dePresno      The Last of the Romantics EP    7.0
# 198       Tom Grennan  Found What I've Been Looking For    6.9
# 190  Michael McDonald                         Wide Open    6.5
# 155       Fleet Foxes                          Crack-Up    6.5
# 232            Fergie                   Double Dutchess    6.0
# 245      Leon Russell                On a Distant Shore    6.0
# 238         Tim Barry                        High on 95    5.9
# 142       Lostboycrow        Traveler: The First Legend    5.5
# 243    Princess Nokia                       1992 Deluxe    5.3
# 157       Jack & Jack                              GONE    5.0
# 184    Blood Cultures                    Happy Birthday    4.0
# 267        Tony Allen                        The Source    0.0

# %%
# groupby singer

# %%
groupbysinger = alldata.groupby('Who').groups

# %%
groupbysinger
# Out:
# {' Alicia Keys': Int64Index([116], dtype='int64'),
#  ' Apollo Brown & Planet Asia': Int64Index([203], dtype='int64'),
#  ' Arcade Fire': Int64Index([42], dtype='int64'),
#  ' Broken Bells': Int64Index([92], dtype='int64'),
#  ' Ellie Goulding': Int64Index([88], dtype='int64'),
#  ' James Bay': Int64Index([106], dtype='int64'),
#  ' Niia': Int64Index([235], dtype='int64'),
#  'A Tribe Called Quest': Int64Index([75], dtype='int64'),
#  'ANOHNI': Int64Index([31], dtype='int64'),
#  'Adele': Int64Index([44], dtype='int64'),
#  'Albin Lee Meldau': Int64Index([208], dtype='int64'),
#  'Alex Clare': Int64Index([89, 114, 115], dtype='int64'),
#  'Alex Hahn': Int64Index([266], dtype='int64'),
#  'Alexander Biggs': Int64Index([194], dtype='int64'),
#  'Alexandra Savior': Int64Index([176], dtype='int64'),
#  'Alt-J': Int64Index([211], dtype='int64'),
#  'Alvvays': Int64Index([283], dtype='int64'),
#  'Amy Winehouse': Int64Index([46], dtype='int64'),
#  'Anderson .Paak': Int64Index([112], dtype='int64'),
#  'Arcade Fire': Int64Index([215], dtype='int64'),
#  'Arctic Monkeys': Int64Index([66, 193], dtype='int64'),
#  'Aretha Franklin': Int64Index([128], dtype='int64'),
#  'Bad Boys Blue': Int64Index([174, 175], dtype='int64'),
#  'Bad Sounds': Int64Index([257], dtype='int64'),
#  'Badbadnotgood': Int64Index([255, 256], dtype='int64'),
#  'Bastille': Int64Index([68], dtype='int64'),
#  'Beck': Int64Index([273], dtype='int64'),
#  'Bee Gees': Int64Index([228], dtype='int64'),
#  'Benjamin Clementine': Int64Index([254], dtype='int64'),
#  'Beyoncé': Int64Index([100], dtype='int64'),
#  'Bleachers': Int64Index([147], dtype='int64'),
#  'Blondie': Int64Index([63], dtype='int64'),
#  'Blood Cultures': Int64Index([184], dtype='int64'),
#  'Blossoms': Int64Index([140], dtype='int64'),
#  'Bombay Bicycle Club': Int64Index([90], dtype='int64'),
#  'Brockhampton': Int64Index([192], dtype='int64'),
#  'Charlie Puth': Int64Index([94], dtype='int64'),
#  'Charlotte Cardin': Int64Index([239], dtype='int64'),
#  'Childish Gambino': Int64Index([16, 24], dtype='int64'),
#  'Chrome Sparks': Int64Index([10], dtype='int64'),
#  'Coldplay': Int64Index([35, 36, 37], dtype='int64'),
#  'Daft Punk': Int64Index([7, 200], dtype='int64'),
#  'Dan Auerbach': Int64Index([153], dtype='int64'),
#  'Dan Croll': Int64Index([207], dtype='int64'),
#  'Daniel Shake': Int64Index([85], dtype='int64'),
#  'Dean Martin': Int64Index([41], dtype='int64'),
#  'Death Cab for Cutie': Int64Index([196], dtype='int64'),
#  'Declan McKenna': Int64Index([185], dtype='int64'),
#  'Depeche Mode': Int64Index([39, 40, 170], dtype='int64'),
#  'Dire Straits': Int64Index([55], dtype='int64'),
#  'Dive Deep': Int64Index([240], dtype='int64'),
#  'Drake': Int64Index([158, 159, 160], dtype='int64'),
#  'Dusty Springfield': Int64Index([129], dtype='int64'),
#  'Ed Sheeran': Int64Index([26, 27, 61], dtype='int64'),
#  'Elbow': Int64Index([145], dtype='int64'),
#  'Elli Ingram': Int64Index([247], dtype='int64'),
#  'Elton John': Int64Index([34], dtype='int64'),
#  'Elvis Presley': Int64Index([131], dtype='int64'),
#  'Everything Everything': Int64Index([152], dtype='int64'),
#  'Father John Misty': Int64Index([227], dtype='int64'),
#  'Fergie': Int64Index([232], dtype='int64'),
#  'Fleet Foxes': Int64Index([155], dtype='int64'),
#  'Florence + The Machine': Int64Index([119], dtype='int64'),
#  'Foals': Int64Index([91], dtype='int64'),
#  'Foster The People': Int64Index([179], dtype='int64'),
#  'Francis and the Lights': Int64Index([22], dtype='int64'),
#  'Frank Ocean': Int64Index([136], dtype='int64'),
#  'Franz Ferdinand': Int64Index([183], dtype='int64'),
#  'Glass Animals': Int64Index([33], dtype='int64'),
#  'Gregory Porter': Int64Index([45], dtype='int64'),
#  'Harrison Storm': Int64Index([236], dtype='int64'),
#  'Harry Styles': Int64Index([123], dtype='int64'),
#  'Hurts': Int64Index([250], dtype='int64'),
#  'Hus': Int64Index([258], dtype='int64'),
#  'Ibeyi': Int64Index([252], dtype='int64'),
#  'Imagine Dragons': Int64Index([146, 164, 172, 210], dtype='int64'),
#  'Ivan Dorn': Int64Index([109], dtype='int64'),
#  'JP Cooper': Int64Index([263], dtype='int64'),
#  'Jack & Jack': Int64Index([157], dtype='int64'),
#  'Jacob Sartorius': Int64Index([265], dtype='int64'),
#  'Jake Bugg': Int64Index([214], dtype='int64'),
#  'James Vincent McMorrow': Int64Index([8], dtype='int64'),
#  'Jamie Lawson': Int64Index([253], dtype='int64'),
#  'Jamiroquai': Int64Index([76], dtype='int64'),
#  'Jason Derulo': Int64Index([99], dtype='int64'),
#  'Jazmine Sullivan': Int64Index([221], dtype='int64'),
#  'Jean Michel Jarre': Int64Index([173], dtype='int64'),
#  'Julian Casablancas': Int64Index([279], dtype='int64'),
#  'Julie Byrne': Int64Index([139], dtype='int64'),
#  'Justin Timberlake': Int64Index([102], dtype='int64'),
#  'Kaleo': Int64Index([224], dtype='int64'),
#  'Kamasi Washingtom': Int64Index([249], dtype='int64'),
#  'Kanye West': Int64Index([105], dtype='int64'),
#  'Katy Perry': Int64Index([117], dtype='int64'),
#  'Kele Okereke': Int64Index([262], dtype='int64'),
#  'Kelis': Int64Index([104], dtype='int64'),
#  'Kendrick Lamar': Int64Index([138], dtype='int64'),
#  'Kings of Leon': Int64Index([13], dtype='int64'),
#  'Kraftwerk': Int64Index([154], dtype='int64'),
#  'LP': Int64Index([126], dtype='int64'),
#  'Lady Gaga': Int64Index([15, 86], dtype='int64'),
#  'Lafa Taylor, Aabo': Int64Index([181], dtype='int64'),
#  'Lana Del Rey': Int64Index([180], dtype='int64'),
#  'Lenny Williams': Int64Index([133], dtype='int64'),
#  'Leon Russell': Int64Index([245], dtype='int64'),
#  'Leon Vynehall': Int64Index([52], dtype='int64'),
#  'Liam Gallagher': Int64Index([259], dtype='int64'),
#  'Little Richard': Int64Index([132], dtype='int64'),
#  'London Grammar': Int64Index([150], dtype='int64'),
#  'Lorde': Int64Index([87, 151], dtype='int64'),
#  'Lostboycrow': Int64Index([142], dtype='int64'),
#  'Lowland Hum': Int64Index([237], dtype='int64'),
#  'MS MR': Int64Index([9], dtype='int64'),
#  'Mac DeMarco': Int64Index([93], dtype='int64'),
#  'Macintosh Plus': Int64Index([229], dtype='int64'),
#  'Macklemore': Int64Index([234], dtype='int64'),
#  'Majid Jordan': Int64Index([282], dtype='int64'),
#  'Major Lazer': Int64Index([143], dtype='int64'),
#  'Mando Diao': Int64Index([127], dtype='int64'),
#  'Mark Ronson': Int64Index([122], dtype='int64'),
#  'Maroon 5': Int64Index([83, 84, 217, 280], dtype='int64'),
#  'Marvin Gaye': Int64Index([191], dtype='int64'),
#  'Matt Corby': Int64Index([81], dtype='int64'),
#  'Matt Wills': Int64Index([69, 70, 71, 73], dtype='int64'),
#  'Mayer Hawthorne': Int64Index([202, 204, 206], dtype='int64'),
#  'Meghan Trainor': Int64Index([95], dtype='int64'),
#  'Michael Jackson': Int64Index([205], dtype='int64'),
#  'Michael McDonald': Int64Index([190], dtype='int64'),
#  'Miley Cyrus': Int64Index([251], dtype='int64'),
#  'Missy Elliott': Int64Index([162], dtype='int64'),
#  'Moby': Int64Index([97], dtype='int64'),
#  'Modern Talking': Int64Index([6], dtype='int64'),
#  'Morgan Saint': Int64Index([275], dtype='int64'),
#  'Mr Jukes': Int64Index([182], dtype='int64'),
#  'Mura Masa': Int64Index([209], dtype='int64'),
#  'Muse': Int64Index([48, 49, 50, 51, 53, 54], dtype='int64'),
#  'MØ': Int64Index([19], dtype='int64'),
#  'N Sync': Int64Index([141], dtype='int64'),
#  'New Politics': Int64Index([261], dtype='int64'),
#  'Nothing But Thieves': Int64Index([216], dtype='int64'),
#  'Oddisee': Int64Index([120, 121], dtype='int64'),
#  'Of Monsters and Men': Int64Index([118], dtype='int64'),
#  'One Direction': Int64Index([21, 134], dtype='int64'),
#  'One Republic': Int64Index([110, 111], dtype='int64'),
#  'P!nk': Int64Index([272], dtype='int64'),
#  'PARTYNEXTDOOR': Int64Index([28], dtype='int64'),
#  'Panic! At The Disco': Int64Index([0, 4, 5, 29, 30], dtype='int64'),
#  'Parov Stelar': Int64Index([113], dtype='int64'),
#  'Perfume Genius': Int64Index([137], dtype='int64'),
#  'Pink Floyd - Dark Side Of The Moon (Full Album)': Int64Index([177], dtype='int64'),
#  'Police': Int64Index([38], dtype='int64'),
#  'Pond': Int64Index([124], dtype='int64'),
#  'Portugal. The Man': Int64Index([156], dtype='int64'),
#  'Post Malone': Int64Index([74], dtype='int64'),
#  'Prince, Prince And The Revolution': Int64Index([149], dtype='int64'),
#  'Princess Nokia': Int64Index([243], dtype='int64'),
#  'ROSTAM': Int64Index([242], dtype='int64'),
#  "Rag'n'Bone Man": Int64Index([60], dtype='int64'),
#  'Rationale': Int64Index([264], dtype='int64'),
#  'Rex': Int64Index([222], dtype='int64'),
#  'Rex Orange County': Int64Index([223], dtype='int64'),
#  'Rhodes': Int64Index([1, 2, 3, 77, 78], dtype='int64'),
#  'Rivulets': Int64Index([225, 226], dtype='int64'),
#  'Robbie Williams': Int64Index([168], dtype='int64'),
#  'Royal Blood': Int64Index([161], dtype='int64'),
#  'Róisín Murphy': Int64Index([284], dtype='int64'),
#  'SZA': Int64Index([230], dtype='int64'),
#  'Sam Smith': Int64Index([281], dtype='int64'),
#  'Sampha': Int64Index([58], dtype='int64'),
#  'San Cisco': Int64Index([47], dtype='int64'),
#  'Say Lou Lou': Int64Index([11], dtype='int64'),
#  'Scarlett Johansson, Pete Yorn': Int64Index([189], dtype='int64'),
#  'Seafret': Int64Index([80], dtype='int64'),
#  'Shawn Mendes': Int64Index([96], dtype='int64'),
#  'Shekhinah': Int64Index([271], dtype='int64'),
#  'Snoop Dogg': Int64Index([135], dtype='int64'),
#  'Solange': Int64Index([56], dtype='int64'),
#  'Sparks': Int64Index([167], dtype='int64'),
#  'Speedometer': Int64Index([17], dtype='int64'),
#  'St. Vincent': Int64Index([20, 274], dtype='int64'),
#  'Stella': Int64Index([62], dtype='int64'),
#  'Stevie Wonder': Int64Index([130], dtype='int64'),
#  'Syd': Int64Index([219], dtype='int64'),
#  'TOKiMONSTA': Int64Index([260], dtype='int64'),
#  'Take That': Int64Index([163, 165], dtype='int64'),
#  'Tame Impala': Int64Index([12], dtype='int64'),
#  'The 1975': Int64Index([197], dtype='int64'),
#  'The Avalanches': Int64Index([79], dtype='int64'),
#  'The Beatles': Int64Index([187, 188], dtype='int64'),
#  'The Belligerents': Int64Index([220], dtype='int64'),
#  'The Black Eyed Peas': Int64Index([32], dtype='int64'),
#  'The Black Keys': Int64Index([199, 201], dtype='int64'),
#  'The Killers': Int64Index([231], dtype='int64'),
#  'The Kinks': Int64Index([166], dtype='int64'),
#  'The Miseducation of Lauryn Hill': Int64Index([148], dtype='int64'),
#  'The National': Int64Index([268], dtype='int64'),
#  'The Rolling Stones': Int64Index([248], dtype='int64'),
#  'The Strokes': Int64Index([276, 277, 278], dtype='int64'),
#  'The War On Drugs': Int64Index([98, 101, 246], dtype='int64'),
#  'The xx': Int64Index([18], dtype='int64'),
#  'Thomas Azier': Int64Index([125], dtype='int64'),
#  'Thundercat': Int64Index([57], dtype='int64'),
#  'Tim Barry': Int64Index([238], dtype='int64'),
#  'Timbaland': Int64Index([67], dtype='int64'),
#  'Todd Terje': Int64Index([82], dtype='int64'),
#  'Tom Grennan': Int64Index([198], dtype='int64'),
#  'Tony Allen': Int64Index([267], dtype='int64'),
#  'Toro Y Moi': Int64Index([171], dtype='int64'),
#  'Tricky': Int64Index([233], dtype='int64'),
#  'Two Door Cinema Club': Int64Index([14], dtype='int64'),
#  'Tyler, The Creator': Int64Index([186], dtype='int64'),
#  'Unknown Mortal Orchestra': Int64Index([218], dtype='int64'),
#  'Unseen Keys': Int64Index([241], dtype='int64'),
#  'Valerie June': Int64Index([107], dtype='int64'),
#  'Vampire Weekend': Int64Index([195], dtype='int64'),
#  'Weeknd': Int64Index([23], dtype='int64'),
#  'White Lies': Int64Index([59, 72, 103], dtype='int64'),
#  'Whitney Houston': Int64Index([65], dtype='int64'),
#  'Xxxtentacion': Int64Index([244], dtype='int64'),
#  'Years & Years': Int64Index([43, 169], dtype='int64'),
#  'Zara Larsson': Int64Index([108], dtype='int64'),
#  'Zayn': Int64Index([25], dtype='int64'),
#  'alt-J': Int64Index([144, 212, 213], dtype='int64'),
#  'dePresno': Int64Index([269, 270], dtype='int64'),
#  'wish you were here': Int64Index([178], dtype='int64'),
#  'Иван Дорн': Int64Index([64], dtype='int64')}

# %%
groupbysinger.keys()
# Out:
russell', 'Muse', 'Michael McDonald', 'Julie Byrne', 'Drake', 'Florence + The Machine', 'MS MR', 'Bastille', 'LP', 'Whitney Houston', 'Bee Gees', 'Blood Cultures', 'Kraftwerk', 'Elton John', 'Tricky', 'New Politics', 'Unseen Keys', 'Mayer Hawthorne', 'James Vincent McMorrow', 'Major Lazer', 'Dive Deep', 'Royal Blood', 'Pond', 'Todd Terje', 'alt-J', 'The xx', 'Lenny Williams', 'Tame Impala', 'The Killers', 'Prince, Prince And The Revolution', 'Tom Grennan', 'Shawn Mendes', 'Róisín Murphy', 'Foster The People', 'Robbie Williams', 'The Kinks', 'One Direction', 'The National', 'Meghan Trainor', 'Lostboycrow', 'Kings of Leon', 'Kele Okereke', 'Mac DeMarco', 'Ed Sheeran', 'Mura Masa', 'Иван Дорн', 'White Lies', 'Katy Perry', 'Aretha Franklin', 'Bad Sounds', 'TOKiMONSTA', 'Unknown Mortal Orchestra', 'Weeknd', 'Princess Nokia', 'Ibeyi', 'Dan Croll'])

# %%
from collections import Counter
counter = Counter(alldata['Who'])

# %%
counter.most_common()
# Out:
# [('Muse', 6),
#  ('Panic! At The Disco', 5),
#  ('Rhodes', 5),
#  ('Imagine Dragons', 4),
#  ('Maroon 5', 4),
#  ('Matt Wills', 4),
#  ('White Lies', 3),
#  ('Depeche Mode', 3),
#  ('The War On Drugs', 3),
#  ('The Strokes', 3),
#  ('Alex Clare', 3),
#  ('Mayer Hawthorne', 3),
#  ('Coldplay', 3),
#  ('alt-J', 3),
#  ('Ed Sheeran', 3),
#  ('Drake', 3),
#  ('Badbadnotgood', 2),
#  ('dePresno', 2),
#  ('Years & Years', 2),
#  ('One Direction', 2),
#  ('Take That', 2),
#  ('Rivulets', 2),
#  ('The Black Keys', 2),
#  ('St. Vincent', 2),
#  ('Daft Punk', 2),
#  ('Lady Gaga', 2),
#  ('One Republic', 2),
#  ('The Beatles', 2),
#  ('Childish Gambino', 2),
#  ('Oddisee', 2),
#  ('Lorde', 2),
#  ('Bad Boys Blue', 2),
#  ('Arctic Monkeys', 2),
#  ('Declan McKenna', 1),
#  ('Kanye West', 1),
#  ('Thomas Azier', 1),
#  ('Tim Barry', 1),
#  ('Amy Winehouse', 1),
#  ('The Miseducation of Lauryn Hill', 1),
#  ('Brockhampton', 1),
#  ('Arcade Fire', 1),
#  ('Vampire Weekend', 1),
#  ('Alexander Biggs', 1),
#  ('Scarlett Johansson, Pete Yorn', 1),
#  ('Macintosh Plus', 1),
#  ('ROSTAM', 1),
#  ('Michael Jackson', 1),
#  ('Rex Orange County', 1),
#  ('The Avalanches', 1),
#  ('Dive Deep', 1),
#  (' Niia', 1),
#  ('Moby', 1),
#  ('JP Cooper', 1),
#  ('Matt Corby', 1),
#  ('Timbaland', 1),
#  ('Morgan Saint', 1),
#  ('A Tribe Called Quest', 1),
#  ('Harry Styles', 1),
#  ('Valerie June', 1),
#  ('Marvin Gaye', 1),
#  ('Franz Ferdinand', 1),
#  ('Zayn', 1),
#  ('Hus', 1),
#  ('Glass Animals', 1),
#  ('Kendrick Lamar', 1),
#  ('Justin Timberlake', 1),
#  ('PARTYNEXTDOOR', 1),
#  ('Jack & Jack', 1),
#  ('Blossoms', 1),
#  ('Blondie', 1),
#  ('The Black Eyed Peas', 1),
#  ('ANOHNI', 1),
#  ('Meghan Trainor', 1),
#  ('Rationale', 1),
#  ('Missy Elliott', 1),
#  ('Pink Floyd - Dark Side Of The Moon (Full Album)', 1),
#  ('Macklemore', 1),
#  ('Alt-J', 1),
#  ('Beyoncé', 1),
#  ('Julian Casablancas', 1),
#  ('Weeknd', 1),
#  ('Tyler, The Creator', 1),
#  ('Say Lou Lou', 1),
#  ('Kelis', 1),
#  ('P!nk', 1),
#  ('Jamiroquai', 1),
#  ('Harrison Storm', 1),
#  ('Alexandra Savior', 1),
#  ('Sparks', 1),
#  ('MS MR', 1),
#  ('San Cisco', 1),
#  ('Majid Jordan', 1),
#  ('Shekhinah', 1),
#  ('N Sync', 1),
#  ('Jacob Sartorius', 1),
#  ('Parov Stelar', 1),
#  ('Hurts', 1),
#  ('Иван Дорн', 1),
#  ('Modern Talking', 1),
#  ('Fleet Foxes', 1),
#  ('The Belligerents', 1),
#  ('Albin Lee Meldau', 1),
#  ('Adele', 1),
#  ('Perfume Genius', 1),
#  ('Zara Larsson', 1),
#  ('Stella', 1),
#  ('Jake Bugg', 1),
#  ('Sampha', 1),
#  ('Charlotte Cardin', 1),
#  ('Seafret', 1),
#  ('The 1975', 1),
#  ('Alvvays', 1),
#  ('Daniel Shake', 1),
#  (' Alicia Keys', 1),
#  ('Police', 1),
#  ('Post Malone', 1),
#  ('Dean Martin', 1),
#  (' Apollo Brown & Planet Asia', 1),
#  ('Stevie Wonder', 1),
#  ('Frank Ocean', 1),
#  ('Mark Ronson', 1),
#  ('Alex Hahn', 1),
#  ('Pond', 1),
#  ('The xx', 1),
#  ('Elli Ingram', 1),
#  ('Elvis Presley', 1),
#  ('Jazmine Sullivan', 1),
#  ('Fergie', 1),
#  ('Leon Vynehall', 1),
#  ('London Grammar', 1),
#  ('Death Cab for Cutie', 1),
#  ('Dan Auerbach', 1),
#  ('Miley Cyrus', 1),
#  ('Foals', 1),
#  ('Toro Y Moi', 1),
#  ('Dire Straits', 1),
#  ('Rex', 1),
#  ('Snoop Dogg', 1),
#  ('Francis and the Lights', 1),
#  ('Two Door Cinema Club', 1),
#  ('The Killers', 1),
#  ('Charlie Puth', 1),
#  ('Beck', 1),
#  ('Little Richard', 1),
#  ('Sam Smith', 1),
#  ('SZA', 1),
#  ('Nothing But Thieves', 1),
#  ('Lafa Taylor, Aabo', 1),
#  ('Chrome Sparks', 1),
#  ('Everything Everything', 1),
#  ('Lowland Hum', 1),
#  ('Kaleo', 1),
#  ('Benjamin Clementine', 1),
#  ('Solange', 1),
#  ('New Politics', 1),
#  ('MØ', 1),
#  ('Thundercat', 1),
#  ('Lana Del Rey', 1),
#  ('Xxxtentacion', 1),
#  ('Liam Gallagher', 1),
#  ('wish you were here', 1),
#  (' Arcade Fire', 1),
#  ('Ivan Dorn', 1),
#  ('Tony Allen', 1),
#  ('Kings of Leon', 1),
#  ('Mr Jukes', 1),
#  ('Mando Diao', 1),
#  ("Rag'n'Bone Man", 1),
#  (' James Bay', 1),
#  ('Elbow', 1),
#  ('Kamasi Washingtom', 1),
#  ('Father John Misty', 1),
#  ('Portugal. The Man', 1),
#  ('Anderson .Paak', 1),
#  ('Jamie Lawson', 1),
#  ('Jean Michel Jarre', 1),
#  (' Broken Bells', 1),
#  ('Of Monsters and Men', 1),
#  ('Jason Derulo', 1),
#  ('The Rolling Stones', 1),
#  ('TOKiMONSTA', 1),
#  ('Bombay Bicycle Club', 1),
#  ('Gregory Porter', 1),
#  ('Leon Russell', 1),
#  ('Michael McDonald', 1),
#  ('Julie Byrne', 1),
#  ('Dusty Springfield', 1),
#  ('Florence + The Machine', 1),
#  ('Bastille', 1),
#  ('Bad Sounds', 1),
#  ('Whitney Houston', 1),
#  ('Bee Gees', 1),
#  ('Blood Cultures', 1),
#  ('Kraftwerk', 1),
#  ('Elton John', 1),
#  ('Tricky', 1),
#  (' Ellie Goulding', 1),
#  ('Unseen Keys', 1),
#  ('James Vincent McMorrow', 1),
#  ('Major Lazer', 1),
#  ('Princess Nokia', 1),
#  ('Royal Blood', 1),
#  ('Todd Terje', 1),
#  ('Tame Impala', 1),
#  ('Bleachers', 1),
#  ('Prince, Prince And The Revolution', 1),
#  ('Tom Grennan', 1),
#  ('Shawn Mendes', 1),
#  ('Róisín Murphy', 1),
#  ('Foster The People', 1),
#  ('Robbie Williams', 1),
#  ('The Kinks', 1),
#  ('Syd', 1),
#  ('The National', 1),
#  ('Lostboycrow', 1),
#  ('Kele Okereke', 1),
#  ('Mac DeMarco', 1),
#  ('Dan Croll', 1),
#  ('Speedometer', 1),
#  ('Katy Perry', 1),
#  ('Aretha Franklin', 1),
#  ('LP', 1),
#  ('Unknown Mortal Orchestra', 1),
#  ('Lenny Williams', 1),
#  ('Ibeyi', 1),
#  ('Mura Masa', 1)]

# %%
Counter(alldata['Score']).most_common()
# Out:
# [(8.0, 60),
#  (9.0, 31),
#  (7.0, 28),
#  (8.5, 27),
#  (7.5, 21),
#  (10.0, 20),
#  (9.5, 18),
#  (8.6, 7),
#  (8.1, 6),
#  (6.0, 6),
#  (7.9, 6),
#  (8.7, 6),
#  (8.3, 6),
#  (7.8, 5),
#  (6.5, 4),
#  (9.8, 4),
#  (0.0, 3),
#  (8.9, 3),
#  (7.7, 3),
#  (9.1, 3),
#  (7.3, 2),
#  (8.4, 2),
#  (7.6, 2),
#  (5.9, 1),
#  (4.0, 1),
#  (5.0, 1),
#  (11.0, 1),
#  (9.9, 1),
#  (9.4, 1),
#  (9.7, 1),
#  (5.5, 1),
#  (8.2, 1),
#  (5.3, 1),
#  (6.9, 1),
#  (8.8, 1)]

# %%
url = 'https://music.yandex.ru/album/53485'
import requests
r = requests.get(url)

# %%
r.text
# Out:
# '<!DOCTYPE html><html><head><meta http-equiv="X-UA-Compatible" content="IE=EmulateIE7,IE=edge" /><meta http-equiv="Content-type" content="text/html; charset=utf-8" /><meta http-equiv="Content-language" content="ru"/><link rel="alternate" hreflang="en" type="text/html" href="https://music.yandex.ru/album/53485?lang=en"/><meta name="viewport" content="width=device-width, initial-scale=0.7"><!-- Отключаем плагин SkypeClick2Call --><meta name="skype_toolbar" content="skype_toolbar_parser_compatible" /><title>Pretty. Odd. — Panic! At The Disco. Слушать онлайн на Яндекс.Музыке</title><meta name="description" content="Pretty. Odd. — Panic! At The Disco. Открывайте новую музыку каждый день. Лента с персональными рекомендациями и музыкальными новинками, радио, подборки на любой вкус, удобное управление своей коллекцией. Миллионы композиций бесплатно и в хорошем качестве."/><link rel="image_src" href="https://avatars.yandex.net/get-music-content/33216/12e3ef14.a.53485-4/m1000x1000"/><meta property="og:title" content="Pretty. Odd. — Panic! At The Disco"/><meta property="og:description" content="Слушайте на Яндекс.Музыке"/><meta property="og:image" content="https://avatars.yandex.net/get-music-content/33216/12e3ef14.a.53485-4/m1000x1000"/><meta property="og:type" content="music.album"/><meta property="og:url" content="https://music.yandex.ru/album/53485"/><meta property="og:site_name" content="Яндекс.Музыка"/><meta property="fb:app_id" content="117328825040925"/><meta property="og:locale" content="ru_RU"/><meta property="music:musician" content="https://music.yandex.ru/artist/45303"/><meta property="og:audio" content="https://music.yandex.ru/album/53485?play=1"/><meta name="twitter:card" content="summary_large_image"/><meta name="twitter:title" content="Pretty. Odd. — Panic! At The Disco"/><meta name="twitter:site" content="@yandexmusic"/><meta name="twitter:app:country" content="RU"/><meta name="twitter:app:name:iphone" content="Яндекс.Музыка"/><meta name="twitter:app:id:iphone" content="520797969"/><meta name="twitter:app:url:iphone" content="yandexmusic://album/53485"/><meta property="al:ios:app_store_id" content="520797969"/><meta property="al:ios:app_name" content="Яндекс.Музыка"/><meta property="al:ios:url" content="yandexmusic://album/53485"/><meta property="al:web:url" content="https://music.yandex.ru/album/53485"/><script class="light-data" type="application/ld+json" nonce="DOL4deLupMltl0M5OhnfgQ==">{"@context": "http://schema.org","@type": "MusicAlbum","description": "Pretty. Odd. - Panic! At The Disco - альбом на Яндекс.Музыке","byArtist": {"@type": "MusicGroup","name": "Panic! At The Disco","url": "/artist/45303"},"name": "Pretty. Odd.","numTracks": "16","genre": "rock","image": "https://avatars.yandex.net/get-music-content/33216/12e3ef14.a.53485-4/m1000x1000","url": "/album/53485","track": [{"@type": "MusicRecording","duration": "PT1M21S","name": "We\'re So Starving","url": "/album/53485/track/208942"},{"@type": "MusicRecording","duration": "PT3M11S","name": "Nine In The Afternoon","url": "/album/53485/track/208707"},{"@type": "MusicRecording","duration": "PT3M12S","name": "She\'s A Handsome Woman","url": "/album/53485/track/208936"},{"@type": "MusicRecording","duration": "PT4M14S","name": "Do You Know What I\'m Seeing?","url": "/album/53485/track/208944"},{"@type": "MusicRecording","duration": "PT3M15S","name": "That Green Gentleman (Things Have Changed)","url": "/album/53485/track/208945"},{"@type": "MusicRecording","duration": "PT1M56S","name": "I Have Friends In Holy Spaces","url": "/album/53485/track/208946"},{"@type": "MusicRecording","duration": "PT4M7S","name": "Northern Downpour","url": "/album/53485/track/208939"},{"@type": "MusicRecording","duration": "PT4M53S","name": "When The Day Met The Night","url": "/album/53485/track/208935"},{"@type": "MusicRecording","duration": "PT2M39S","name": "Pas De Cheval","url": "/album/53485/track/208943"},{"@type": "MusicRecording","duration": "PT3M43S","name": "The Piano Knows So ...
